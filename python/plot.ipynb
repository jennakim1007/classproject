# %%
import wordcloud
text = 'python python hello data'
wc = wordcloud.WordCloud()
wc.generate_from_text(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# wordcloud
import wordcloud
text = 'python python hello data data data data'
wc = wordcloud.WordCloud()
wc.generate_from_text(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
text = {'python':10, 'hello':1, 'data':4}
wc = wordcloud.WordCloud()
wc.generate_from_frequencies(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
text = '파이썬 파이썬 시각화 데이터분석 오류 데이터'
font_path = '/Windows/Fonts/batang.ttc'
wc = wordcloud.WordCloud(font_path=font_path, background_color='pink', stopwords=['오류', '데이터'])
wc.generate_from_text(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>
